# %%
install.packages("MASS", repos="http://cran.rstudio.com/")
require(MASS)
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loading required package: MASS

# %%
# Set the correlation parameter and mean
beta = 0.5
SIGMA = matrix(c(1,beta,beta,1), ncol=2)
MU = c(2.0, 1.0)

# Set the sample size
N = 50

# Draw your sample
out <- mvrnorm(N, mu = MU, Sigma = SIGMA)

# %%
# Look at a section of the data
dim(out)
out[1:10,]
# Out:
# [1] 50  2
#            [,1]       [,2]
#  [1,] 2.7061052  2.1808029
#  [2,] 0.9396117 -0.5690758
#  [3,] 2.5559191  1.5033604
#  [4,] 1.6119058  1.3883720
#  [5,] 2.3003149 -0.2432755
#  [6,] 2.8269815  0.5225713
#  [7,] 1.3448575  0.5858371
#  [8,] 2.8747481  1.7077267
#  [9,] 2.9906919  2.0466183
# [10,] 1.1771496  2.2436461

# %%
plot(out)
# Out:
# plot without title

# %%
plot(out)
abline(lm(out[,2]~out[,1]), col="red") # regression line (y~x)
# Out:
# plot without title
